# %% [markdown]
# # <center> 作业三 All-Dogs </center>
# by Hyr1sky_He
#
# _为了提高任务效率，本ipynb中不再细化每个步骤的操作过程，仅记录重要思路及核心方法，Task题目解答将在实验报告中给出_

# %%
import numpy as np
import pandas as pd
import torch
import time
import os
import cv2
import torch.nn as nn
import torch.utils.data as data
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from PIL import Image
from pathlib import Path
from torchvision.utils import save_image
from torchvision.datasets import DatasetFolder, ImageFolder
# %matplotlib inline

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# %%
# Constant
BATCH_SIZE = 256
EPOCHS = 50
LR = 0.001
WEIGHT_DECAY = 0

# %%
# Load data
root = '/kaggle/input/all-dog-data/'
all_images = os.listdir(root)
print(len(all_images))

idx = np.random.randint(0, len(all_images))
sample_img = Image.open(root + all_images[idx])
plt.imshow(sample_img)
print(sample_img.size)

# %%
# define a DataLoader
class UnsupervisedImageDataset(data.Dataset):
    def __init__(self, root, transform=None):
        self.root = root
        self.transform = transform
        self.image_files = os.listdir(root)

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root, self.image_files[idx])
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image

# %%
train_tfm = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)
])

train_set = UnsupervisedImageDataset(root, train_tfm)
Train_Loader = data.DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
print(len(Train_Loader))

# randomly show 5 images in a row
plt.figure(figsize=(15, 5))
for i in range(5):
    idx = np.random.randint(0, len(train_set))
    sample_img = train_set[idx]
    plt.subplot(1, 5, i+1)
    plt.imshow(sample_img.permute(1, 2, 0))
    plt.axis('off')

# %%
# Create a mini-dataloader for testing
MINI_BATCH_SIZE = 64
MINISIZE = 3000
random_idx = np.random.randint(0, len(train_set), MINISIZE)
mini_set = data.Subset(train_set, random_idx)
mini_set.indices = np.arange(MINISIZE)
mini_loader = data.DataLoader(mini_set, batch_size=MINI_BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
print(len(mini_loader.dataset))
print(len(mini_loader))

# %%
"""
About Conv2d:
    in_channels (int) - Number of channels in the input image
    out_channels (int) - Number of channels produced by the convolution
    kernel_size (int or tuple) - Size of the convolving kernel
    stride (int or tuple, optional) - Stride of the convolution. Default: 1
    padding (int or tuple, optional) - Zero-padding added to both sides of the input. Default: 0
    dilation (int or tuple, optional) - Spacing between kernel elements. Default: 1
    groups (int, optional) - Number of blocked connections from input channels to output channels. Default: 1
    bias (bool, optional) - If True, adds a learnable bias to the output. Default: True

    input: (N, C_in, H_in, W_in)
    N: batch size
    C_in: channel of input image
    H_in: height of input image
    W_in: width of input image
"""

class AutoEncoder(nn.Module):
    def __init__(self):
        super(AutoEncoder, self).__init__()

        # Encoder
        # [3, 64, 64] -> [16, 8, 8]
        self.encoder = nn.Sequential(
            # N, 3, 64, 64
            nn.Conv2d(3, 48, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0),
            nn.Conv2d(48, 96, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0),
            nn.Conv2d(96, 192, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(192),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0),
            nn.Conv2d(192, 16, kernel_size=1, stride=1, padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(),
        )

        # Decoder
        # [16, 8, 8] -> [3, 64, 64]
        self.decoder = nn.Sequential(
            nn.Conv2d(16, 192, kernel_size=1, stride=1, padding=0),
            nn.BatchNorm2d(192),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(192, 96, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(96, 48, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(48),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(48, 3, kernel_size=3, stride=1, padding=1),
            nn.Tanh(),
        )

        # Fully connected 
        """
        self.fc1 = nn.Sequential(
            nn.Linear(16*8*8, 128),
        )
        self.fc2 = nn.Sequential(
            nn.Linear(128, 16*8*8),
            nn.BatchNorm1d(16*8*8),
            nn.ReLU(),
        )
        """

    def forward(self, x):
        # return indices
        x = self.encoder(x)
        x = self.decoder(x)
        return x
    
    def get_latent_code(self, x):
        x = self.encoder(x)
        return x.view(x.size(0), -1)  # Flatten the output

    def generate_from_latent_code(self, x):
        # Reshape the latent code
        x = x.view(x.size(0), 16, 8, 8)
        x = self.decoder(x)
        return x
    
"""
model = AutoEncoder()
sample_input = torch.rand((1, 3, 64, 64))
latend_code = model.get_latent_code(sample_input)
print(latend_code.shape)  # suppose output torch.Size([1, 16, 8, 8])
output = model(sample_input)
print(output.shape)  # suppose output torch.Size([1, 3, 64, 64])
print(model)
"""

# %%
class cheat_AE(nn.Module):
    def __init__(self):
        super(cheat_AE, self).__init__()

        # Encoder
        # [3, 64, 64] -> [16, 16, 16]
        self.encoder = nn.Sequential(
            # N, 3, 64, 64
            nn.Conv2d(3, 48, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(48),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0),
            nn.Conv2d(48, 16, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
        )

        # Decoder
        # [16, 32, 32] -> [3, 64, 64]
        self.decoder = nn.Sequential(
            nn.Conv2d(16, 48, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(48),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(48, 3, kernel_size=3, stride=1, padding=1),
            nn.Tanh(),
        )

    def forward(self, x):
        # return indices
        x = self.encoder(x)
        x = self.decoder(x)
        return x
    
    def get_latent_code(self, x):
        x = self.encoder(x)
        return x.view(x.size(0), -1)  # Flatten the output

    def generate_from_latent_code(self, x):
        # Reshape the latent code
        x = x.view(x.size(0), 16, 8, 8)
        x = self.decoder(x)
        return x
    
"""
model = cheat_AE()
sample_input = torch.rand((1, 3, 64, 64))
latend_code = model.get_latent_code(sample_input)
print(latend_code.shape)  # suppose output torch.Size([1, 16, 32, 32])
output = model(sample_input)
print(output.shape)  # suppose output torch.Size([1, 3, 64, 64])
"""

# %%
# Train
class Trainer:
    def __init__(self, model):
        self.model = model
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
        self.criterion = nn.MSELoss()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def train(self, train_loader, epochs):
        # Set up the Directory
        if not os.path.exists('./params'):
            os.mkdir('./params')
        if not os.path.exists('./img'):
            os.mkdir('./img')

        # Print model
        print(self.model)
        self.model.train()
        for epoch in range(epochs):
            total_loss = 0
            start = time.time()

            for batch_idx, data in enumerate(train_loader):
                img = data.to(self.device)
                self.optimizer.zero_grad()
                output = self.model(img)
                loss = self.criterion(output, img)
                loss.backward()
                self.optimizer.step()
                total_loss += loss.item()
                
            end = time.time()
            print('Epoch: {} | Total loss: {:.6f} | Time: {:.2f}s'.format(epoch+1, total_loss, end-start))

            # Save the reconstructed images
            recon_img = output.cpu().data
            real_img = img.cpu().data
            recon_img_V = recon_img[0:5]
            real_img_V = real_img[0:5]
            All_IMG = torch.cat((real_img_V, recon_img_V), 0)
            save_image(All_IMG, './img/Epoch_{}.png'.format(epoch+1), nrow=5)

        # Save model
        torch.save(self.model.state_dict(), './params/autoencoder.pth')
        print('Finished training, model saved!')

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# %%
# Train
model = AutoEncoder().to(device)
trainer = Trainer(model)
trainer.train(Train_Loader, EPOCHS)
# trainer.train(mini_loader, EPOCHS)

# %%
# Show the last 3 sets
plt.figure(figsize=(30, 10))
for i in range(3):
    sample_img = Image.open('./img/Epoch_{}.png'.format(EPOCHS - 2 + i))
    plt.subplot(3, 1, i+1)
    plt.imshow(sample_img)
    plt.axis('off')

# zip the images
import shutil
shutil.make_archive('images', 'zip', './img')

# %%
from torch.utils.data import Subset

# Randomly Show 9 images
idx = np.random.randint(0, len(train_set), 9)
Random_Sample = data.Subset(train_set, idx)
Random_Loader = data.DataLoader(Random_Sample, batch_size=9, shuffle=False, num_workers=4)

for batch_idx, data in enumerate(Random_Loader):
    img = data.to(device)
    output = model(img)
    recon_img = output.cpu().data
    real_img = img.cpu().data
    Latent_Code = model.get_latent_code(img)
    print(Latent_Code.shape)
    All_IMG = torch.cat((real_img, recon_img), 0)
    print(All_IMG.shape)
    
plt.figure(figsize=(30, 30))
for i in range(9):
    plt.subplot(9, 3, i * 3 + 1)
    plt.imshow(real_img[i].permute(1, 2, 0))
    plt.axis('off')
    
    plt.subplot(9, 3, i * 3 + 2)
    latent_code_flat = Latent_Code[i].squeeze().detach().cpu().numpy()
    latent_code_image = torch.reshape(torch.tensor(latent_code_flat), (32, 32)).detach().cpu().numpy()
    plt.imshow(latent_code_image)
    plt.axis('off')
    
    plt.subplot(9, 3, i * 3 + 3)
    plt.imshow(recon_img[i].permute(1, 2, 0))
    plt.axis('off')
    plt.savefig('./img/Contract_{}.png'.format(i+1))

plt.show()

# %%
# Load model
model.load_state_dict(torch.load('./params/autoencoder.pth'))

# Create Ellipse
from matplotlib.patches import Ellipse
import torch.nn.functional as F

img = next(iter(Train_Loader))
model.eval()
with torch.no_grad():
    latent_code = model.encoder(img.to(device))
    Latent_Img = latent_code.reshape((-1, 16 * 8 * 8)).cpu().numpy()
    # print(Latent_Img.shape) # [64, 1024]
    
# Latent_Img = np.linalg.norm(Latent_Img, axis=1)

# print(Latent_Img.shape)
    
# Create Ellipse
d = 0; s = 0
while s < 0.1:
    x = Latent_Img[:, d]
    s = np.std(x)
    d += 1
    
s = 0
while s < 0.1:
    y = Latent_Img[:, d]
    s = np.std(y)
    d += 1

# Calculate the angle
cov = np.cov((x, y))
lambda_, v = np.linalg.eig(cov)
lambda_ = np.sqrt(lambda_)

for j in range(1, 4):
    ell = Ellipse(xy=(np.mean(x), np.mean(y)),
                  width=lambda_[0]*j*2, height=lambda_[1]*j*2,
                  angle=np.rad2deg(np.arccos(v[0, 0])))
    ell.set_facecolor('none')
    ell.set_edgecolor('black')
    plt.gca().add_artist(ell)
    
plt.scatter(x, y)
Samp = np.random.multivariate_normal([np.mean(x), np.mean(y)], cov, 9)
print(Samp)
plt.scatter(Samp[:, 0], Samp[:, 1], c='r', s = 100)
plt.show()

# %%
# Create Subset
Gen_BS = 64
Gen_SZ = 10000
Random_idx = np.random.randint(0, len(train_set), Gen_SZ)
Gen_Set = data.Subset(train_set, Random_idx)
Gen_Set.indices = np.arange(Gen_SZ)
Gen_Loader = data.DataLoader(Gen_Set, batch_size=Gen_BS, shuffle=False, num_workers=4)

Encoded_Gen = []
with torch.no_grad():
    for batch_idx, data in enumerate(Gen_Loader):
        img = data.to(device)
        encoded_img = model.encoder(img)
        encoded_img = encoded_img.reshape((-1, 16 * 8 * 8)).cpu().numpy()
        Mean = np.mean(encoded_img, axis=0)
        Cov = np.cov(encoded_img, rowvar=False)
    print("All images are encoded!")

Generated = []
Generated = np.random.multivariate_normal(Mean, Cov, 9)
Generated = Generated.reshape((-1, 16, 8, 8))
print(Generated.shape)

# %%
# Show Generated
# Generated.shape = (9, 16, 8, 8)

plt.figure(figsize=(30, 30))
for i in range(3):
    plt.figure(figsize=(30, 10))
    plt.subplot(1, 3, 1)
    Input_Gen = torch.from_numpy(Generated[i * 3]).float().unsqueeze(0).to(device)
    Decoded_Gen = model.decoder(Input_Gen).cpu().detach().numpy().squeeze()
    Decoded_Gen = np.transpose(Decoded_Gen, (1, 2, 0))
    plt.imshow(Decoded_Gen)
    plt.axis('off')

    plt.subplot(1, 3, 2)
    Input_Gen = torch.from_numpy(Generated[i * 3 + 1]).float().unsqueeze(0).to(device)
    Decoded_Gen2 = model.decoder(Input_Gen).cpu().detach().numpy().squeeze()
    Decoded_Gen2 = np.transpose(Decoded_Gen2, (1, 2, 0))
    plt.imshow(Decoded_Gen2)
    plt.axis('off')

    plt.subplot(1, 3, 3)
    Input_Gen = torch.from_numpy(Generated[i * 3 + 2]).float().unsqueeze(0).to(device)
    Decoded_Gen3 = model.decoder(Input_Gen).cpu().detach().numpy().squeeze()
    Decoded_Gen3 = np.transpose(Decoded_Gen3, (1, 2, 0))
    plt.imshow(Decoded_Gen3)
    plt.axis('off')
    plt.show()

    # Save
    All_IMG = np.concatenate((Decoded_Gen, Decoded_Gen2, Decoded_Gen3), axis=1)
    save_image(torch.from_numpy(All_IMG).permute(2, 0, 1), './img/Generated_{}.png'.format(i+1), nrow=1)

# %%
"""
We can tell from the Generated images that they don't look like dogs.
So we need to add some constraints to the latent code.
Let's make the latent code a bit closer to the real sampled dots.
"""

Delta = 0.25
Generated = []
Generated = np.random.multivariate_normal(Mean, Cov, 9)
Generated = Delta * Generated + (1 - Delta) * encoded_img[0:9]
Generated = Generated.reshape((-1, 16, 8, 8))
print(Generated.shape)

plt.figure(figsize=(30, 30))
for i in range(3):
    plt.figure(figsize=(30, 10))
    plt.subplot(1, 3, 1)
    Input_Gen = torch.from_numpy(Generated[i * 3]).float().unsqueeze(0).to(device)
    Decoded_Gen = model.decoder(Input_Gen).cpu().detach().numpy().squeeze()
    Decoded_Gen = np.transpose(Decoded_Gen, (1, 2, 0))
    plt.imshow(Decoded_Gen)
    plt.axis('off')

    plt.subplot(1, 3, 2)
    Input_Gen = torch.from_numpy(Generated[i * 3 + 1]).float().unsqueeze(0).to(device)
    Decoded_Gen2 = model.decoder(Input_Gen).cpu().detach().numpy().squeeze()
    Decoded_Gen2 = np.transpose(Decoded_Gen2, (1, 2, 0))
    plt.imshow(Decoded_Gen2)
    plt.axis('off')

    plt.subplot(1, 3, 3)
    Input_Gen = torch.from_numpy(Generated[i * 3 + 2]).float().unsqueeze(0).to(device)
    Decoded_Gen3 = model.decoder(Input_Gen).cpu().detach().numpy().squeeze()
    Decoded_Gen3 = np.transpose(Decoded_Gen3, (1, 2, 0))
    plt.imshow(Decoded_Gen3)
    plt.axis('off')
    plt.show()

    # Save
    All_IMG = np.concatenate((Decoded_Gen, Decoded_Gen2, Decoded_Gen3), axis=1)
    save_image(torch.from_numpy(All_IMG).permute(2, 0, 1), './img/ReGenerated_{}.png'.format(i+1), nrow=1)

# %%
# Add Noise
class add_noise(nn.Module):
    def __init__(self, std):
        super(add_noise, self).__init__()
        self.std = std  # std

    # generate Gaussian noise
    def gaussian_noise_layer(self, input_layer, std, noise_factor = 0.4):
        noise = torch.normal(mean=0.0, std=std, size=input_layer.size()) * noise_factor
        if self.config.CUDA:
            noise = noise.to(input_layer.get_device())
        return input_layer + noise

    # Normalize the latent code
    def normalize(self, x):
        pwr = torch.mean(x ** 2)
        out = x / torch.sqrt(pwr)
        return out

    def forward(self, input):
        latent_code = self.normalize(input)
        noisy_code = self.gaussian_noise_layer(latent_code, self.std)
        return noisy_code
    
# Add Noise to the Generated
Factor = 0.4
Generated = []
Generated = np.random.multivariate_normal(Mean, Cov, 9)
Generated = Delta * Generated + (1 - Delta) * encoded_img[0:9]
Generated = Generated + Factor * np.random.normal(0, 0.1, (9, 1024))
Generated = Generated.reshape((-1, 16, 8, 8))
print(Generated.shape)

plt.figure(figsize=(30, 30))
for i in range(3):
    plt.figure(figsize=(30, 10))
    plt.subplot(1, 3, 1)
    Input_Gen = torch.from_numpy(Generated[i * 3]).float().unsqueeze(0).to(device)
    Decoded_Gen = model.decoder(Input_Gen).cpu().detach().numpy().squeeze()
    Decoded_Gen = np.transpose(Decoded_Gen, (1, 2, 0))
    plt.imshow(Decoded_Gen)
    plt.axis('off')

    plt.subplot(1, 3, 2)
    Input_Gen = torch.from_numpy(Generated[i * 3 + 1]).float().unsqueeze(0).to(device)
    Decoded_Gen2 = model.decoder(Input_Gen).cpu().detach().numpy().squeeze()
    Decoded_Gen2 = np.transpose(Decoded_Gen2, (1, 2, 0))
    plt.imshow(Decoded_Gen2)
    plt.axis('off')

    plt.subplot(1, 3, 3)
    Input_Gen = torch.from_numpy(Generated[i * 3 + 2]).float().unsqueeze(0).to(device)
    Decoded_Gen3 = model.decoder(Input_Gen).cpu().detach().numpy().squeeze()
    Decoded_Gen3 = np.transpose(Decoded_Gen3, (1, 2, 0))
    plt.imshow(Decoded_Gen3)
    plt.axis('off')
    plt.show()

    # Save
    All_IMG = np.concatenate((Decoded_Gen, Decoded_Gen2, Decoded_Gen3), axis=1)
    save_image(torch.from_numpy(All_IMG).permute(2, 0, 1), './img/Noised_Generated_{}.png'.format(i+1), nrow=1)
# Out:
# (9, 16, 8, 8)

# %%
import math

def CalcuPSNR(img1, img2, max_val=255.):
    """
    Based on `tf.image.psnr`
    https://www.tensorflow.org/api_docs/python/tf/image/psnr
    """
    float_type = 'float64'
    # img1 = (torch.clamp(img1,-1,1).cpu().numpy() + 1) / 2 * 255
    # img2 = (torch.clamp(img2,-1,1).cpu().numpy() + 1) / 2 * 255
    img1 = torch.clamp(img1, 0, 1).cpu().detach().numpy() * 255
    img2 = torch.clamp(img2, 0, 1).cpu().detach().numpy() * 255
    img1 = img1.astype(float_type)
    img2 = img2.astype(float_type)
    mse = np.mean(np.square(img1 - img2), axis=(1, 2, 3))
    psnr = 20 * np.log10(max_val) - 10 * np.log10(mse)
    return psnr


def MSE2PSNR(MSE):
    return 10 * math.log10(255 ** 2 / (MSE))

# %%
# Noise
class add_noise(nn.Module):
    def __init__(self, std):
        super(add_noise, self).__init__()
        self.std = std  # std

    # generate Gaussian noise
    def gaussian_noise_layer(self, input_layer, std, noise_factor = 1):
        noise = torch.normal(mean=0.0, std=std, size=input_layer.size()) * noise_factor
        output = input_layer.to(device) + noise.to(device)
        return output

    # Normalize the latent code
    def normalize(self, x):
        pwr = torch.mean(x ** 2)
        out = x / torch.sqrt(pwr)
        return out

    def forward(self, input):
        latent_code = self.normalize(input)
        noisy_code = self.gaussian_noise_layer(latent_code, self.std)
        noisy_code = noisy_code.to(device)
        return noisy_code

# Train
class RealPuppyTrainer:
    def __init__(self, model):
        self.model = model
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
        self.criterion = nn.MSELoss()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.add_noise = add_noise(std=0.15)

    def train(self, train_loader, epochs):
        # Set up the Directory
        if not os.path.exists('./params'):
            os.mkdir('./params')
        if not os.path.exists('./img'):
            os.mkdir('./img')

        # Print model
        print(self.model)
        self.model.train()
        for epoch in range(epochs):
            total_loss = 0.0
            start = time.time()
            psnr = 0.0

            for batch_idx, data in enumerate(train_loader):
                img = data.to(self.device)
                self.optimizer.zero_grad()
                # Noise
                latent_code = self.model.encoder(img)
                noisy_code = self.add_noise(latent_code)
                
                # Normal
                normal_output = self.model.decoder(latent_code)
                output = self.model.decoder(noisy_code)
                
                # BackProp
                loss = self.criterion(output, img)
                loss.backward()
                self.optimizer.step()

                total_loss += loss.item()
                psnr = CalcuPSNR(img, output)
                psnr_noise = CalcuPSNR(normal_output, output)
                
            end = time.time()
            print('Epoch: {} | Total loss: {:.6f} | AVG_PSNR: {:.3f}dB | AVG_noisyPSNR: {:.3f}dB | Time: {:.2f}s'.format(epoch+1, total_loss, np.mean(psnr), np.mean(psnr_noise), end-start))

            # Save the reconstructed images
            noisy_img = output.cpu().data
            recon_img = normal_output.cpu().data
            real_img = img.cpu().data
            noisy_img_V = noisy_img[0:5]
            recon_img_V = recon_img[0:5]
            real_img_V = real_img[0:5]
            All_IMG = torch.cat((real_img_V, recon_img_V, noisy_img_V), 0)
            save_image(All_IMG, './img/Denoising_Epoch_{}.png'.format(epoch+1), nrow=5)

        # Save model
        torch.save(self.model.state_dict(), './params/denoising_autoencoder.pth')
        print('Finished training, model saved!')

# %%
# Train
model = AutoEncoder().to(device)
# model = cheat_AE().to(device)
trainer = RealPuppyTrainer(model)
trainer.train(Train_Loader, EPOCHS)
# trainer.train(mini_loader, EPOCHS)
# Out:
# AutoEncoder(
#   (encoder): Sequential(
#     (0): Conv2d(3, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1))
#     (12): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU()
#   )
#   (decoder): Sequential(
# ...

# %%
idx = np.random.randint(0, len(train_set), 1)
img = Train_Loader.dataset[idx[0]]
img = img.unsqueeze(0).to(device)
print(img.shape)
noise_factor = 0.05
img_slightly_noisy = img + noise_factor * torch.normal(mean=0.0, std=0.1, size=img.size()).to(device)
psnr = CalcuPSNR(img, img_slightly_noisy)
print(psnr)

# show 2 images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img.cpu().data.squeeze().permute(1, 2, 0))
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(img_slightly_noisy.cpu().data.squeeze().permute(1, 2, 0))
plt.axis('off')
plt.show()
# Out:
# torch.Size([1, 3, 64, 64])
# [46.07505505]
